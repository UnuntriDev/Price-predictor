# %% [markdown]
# # Otodom EDA (placeholder)
#
# Phase 2 fills this in once the scraper produces a dataset. Intended
# sections:
#
# 1. Load the raw listings frame (DuckDB / Parquet).
# 2. Validate against `price_predictor.data.schemas.ListingFrame`.
# 3. Univariate distributions: price, area, price/m^2 by city.
# 4. Missingness and outlier review vs. the domain sanity bounds.
# 5. Feature ideas feeding `features.PriceFeaturePipeline`.

# %%
from price_predictor.data.schemas import ListingFrame

list(ListingFrame.to_schema().columns)
